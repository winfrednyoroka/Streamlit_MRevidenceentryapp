# %% [markdown]
# # Check for duplicates in titles and authors of the papers from the References in endnote

# %% [markdown]
#  Aim is to write a function using the dedupe and turn it to an application for deduplicating the records obtained from databases on the basis of titles

# %%
#install pandas-dedupe
# !pip install pandas-dedupe #completed installation

# %%
#import pandas and dedupe libraries

# %%
import pandas as pd #importing pandas
import pandas_dedupe

# %%
#read in the dataframe

dt = pd.read_csv("./Dedup/whitehouse-waves-2014_03.csv")
dt
# Out:
# /var/folders/pn/sqv4n6ms0hnchhr2ll3kh5x00000gq/T/ipykernel_73913/3653918953.py:3: DtypeWarning: Columns (13,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   dt = pd.read_csv("./Dedup/whitehouse-waves-2014_03.csv")
#             NAMELAST NAMEFIRST NAMEMID     UIN    BDGNBR ACCESS_TYPE  \
# 0             Aalami   Arianna       N  U44019       NaN          VA
# 1             Aalami   Florian       B  U44019       NaN          VA
# 2             Aalami    Sophia       J  U44019       NaN          VA
# 3             Aaland      Neil       L  U44410       NaN          VA
# 4        Aalemansour    Hannah     NaN  U51535       NaN          VA
# ...              ...       ...     ...     ...       ...         ...
# 164394     Schermann       Jon       H  U66252       0.0          VA
# 164395       Schield   Brieana       R  U66252       0.0          VA
# 164396  SchieldPrice     Jonah       J  U66252       0.0          VA
# ...

# %%
#help(pandas_dedupe.dedupe_dataframe)
dF = pandas_dedupe.dedupe_dataframe(dt, ['NAMELAST','NAMEFIRST','NAMEMID'])
# Out:
# Importing data ...
# /var/folders/pn/sqv4n6ms0hnchhr2ll3kh5x00000gq/T/ipykernel_73913/4009574177.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dF = pandas_dedupe.dedupe_dataframe(dt, ['NAMELAST','NAMEFIRST','NAMEMID'])
# Reading from dedupe_dataframe_learned_settings
# Clustering...
# # duplicate sets 122967

# %%
dF.to_csv('./Dedup/test.csv')

# %%
emb_coch_med_df = pandas_dedupe.dedupe_dataframe(emb_coch_med, ["Year","Title","Accessionnumber"])
# Out:
# Importing data ...
# Reading from dedupe_dataframe_learned_settings
# Clustering...
# /var/folders/pn/sqv4n6ms0hnchhr2ll3kh5x00000gq/T/ipykernel_73913/3104604941.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   emb_coch_med_df = pandas_dedupe.dedupe_dataframe(emb_coch_med, ["Year","Title","Accessionnumber"])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 emb_coch_med_df = pandas_dedupe.dedupe_dataframe(emb_coch_med, ["Year","Title","Accessionnumber"])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas_dedupe/dedupe_dataframe.py:252, in dedupe_dataframe(df, field_properties, canonicalize, config_name, update_model, threshold, sample_size, n_cores)
#     248 deduper = _train(settings_file, training_file, data_d, field_properties,
# ...
